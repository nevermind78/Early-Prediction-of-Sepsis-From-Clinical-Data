# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,30)
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# patient p000201
#
# patient p000203
#
# patient p000206
#
# patient p001519
#
# patient p008382

# %%
df = pd.read_csv('training/p008382.psv',delimiter='|')

# %%
df
# Out:
#        HR  O2Sat  Temp    SBP   MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  ...  \
# 0    88.0  100.0  35.2  115.0  88.5  74.0  14.0    NaN        -1.0  19.0  ...
# 1    87.5  100.0  35.7  103.0  80.0  67.0  14.0    NaN         0.0  19.0  ...
# 2    88.0  100.0  36.6  102.5  81.5  68.5  14.0    NaN         0.0   NaN  ...
# 3    89.5  100.0  37.2   92.5  74.0  64.0  14.0    NaN         NaN   NaN  ...
# 4    90.0  100.0  37.5   94.0  73.0  63.0  14.0    NaN         NaN   NaN  ...
# ..    ...    ...   ...    ...   ...   ...   ...    ...         ...   ...  ...
# 96   87.0   95.0  37.7  120.0  74.0  51.0  11.0    NaN         NaN   NaN  ...
# 97   87.0   95.0  38.0  122.0  78.0  55.0  30.0    NaN         NaN   NaN  ...
# 98   89.0   95.5  37.9  124.0  80.0  55.0  33.5    NaN         3.0   NaN  ...
# 99   88.0   95.0  37.9  118.0  76.0  53.0  33.0    NaN         3.0   NaN  ...
# 100  88.0   98.0  37.9  131.0  89.0  64.0  31.0    NaN         NaN   NaN  ...
#
#       WBC  Fibrinogen  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  \
# 0    13.5       208.0      106.0  79.05       0      0      1        -4.44
# 1    13.5         NaN        NaN  79.05       0      0      1        -4.44
# 2     NaN         NaN        NaN  79.05       0      0      1        -4.44
# 3     NaN         NaN        NaN  79.05       0      0      1        -4.44
# 4     NaN         NaN        NaN  79.05       0      0      1        -4.44
# ..    ...         ...        ...    ...     ...    ...    ...          ...
# 96    NaN         NaN        NaN  79.05       0      0      1        -4.44
# 97    NaN         NaN        NaN  79.05       0      0      1        -4.44
# 98    NaN         NaN        NaN  79.05       0      0      1        -4.44
# 99    NaN         NaN        NaN  79.05       0      0      1        -4.44
# 100   NaN         NaN        NaN  79.05       0      0      1        -4.44
#
#      ICULOS  SepsisLabel
# 0         2            0
# 1         3            0
# 2         4            0
# 3         5            0
# 4         6            0
# ..      ...          ...
# 96       98            1
# 97       99            1
# 98      100            1
# 99      101            1
# 100     102            1
#
# [101 rows x 41 columns]

# %%
df.plot(subplots=True, legend=True)
plt.show()

# %%
df['HR'].plot(kind='hist')

# %%
plt.rcParams["figure.figsize"] = (20,10)

try :
    df['HR'].plot(kind='kde')
except:
    plt.show()

# %%
df1 = pd.read_csv('training/p001519.psv',delimiter='|')

# %%
try :
    df1.plot(kind='kde')
except:
    pyplot.show()
# Out:
# C:\Users\NeverMind\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:119: RuntimeWarning: All-NaN slice encountered
#   sample_range = np.nanmax(y) - np.nanmin(y)
# C:\Users\NeverMind\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:121: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(y) - 0.5 * sample_range,
# C:\Users\NeverMind\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:122: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(y) + 0.5 * sample_range,

# %%
dff = df.iloc[: , :-1]

# %%
for _,u in enumerate(dff.columns):
    plt.subplot(8,5,_+1)
    try :
        dff[u].plot(kind='hist')
    except:
        df[u].plot(kind='line')
    plt.title(u)
plt.show()
